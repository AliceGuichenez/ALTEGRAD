# %%
import numpy as np
import networkx as nx
from time import time

import GraphData as data
from walks import generate_walks
import pandas as pd
import matplotlib.pyplot as plt

# %%
# To make nice plot for Latex
# %matplotlib notebook
plt.rcParams.update({'font.size': 13}) # for Latex
plt.rcParams['figure.figsize'] = [8, 5]

# %% [markdown]
# # Compute features

# %%
idxs, edgelists = data.get_graphs(N_train = 1000, test = False)
feats = []
for i, edgelist in enumerate(edgelists):
    g = nx.read_edgelist(edgelist)
    feats.append([len(g),
                  nx.density(g),
                  max(nx.core_number(g).values()),
                  
                  ])

feats = pd.DataFrame(feats, index = idxs, columns=["size", "density", "n_core"])
feats.describe()
# Out:
#               size      density       n_core
# count  1000.000000  1000.000000  1000.000000
# mean     17.869000     0.127046     1.921000
# std       2.965575     0.025287     0.277193
# min       9.000000     0.074074     1.000000
# 25%      16.000000     0.110526     2.000000
# 50%      18.000000     0.124183     2.000000
# 75%      20.000000     0.141667     2.000000
# max      27.000000     0.250000     3.000000

# %% [markdown]
# # Analysis

# %%
plt.figure()
feats.boxplot("size")
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
feats.boxplot("density")
# Out:
# <img src="data:image/png;base64,..." width="800">
