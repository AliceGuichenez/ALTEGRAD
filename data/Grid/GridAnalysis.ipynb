# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook

# %%
1645/60
# Out:
# 27.416666666666668

# %%
df = pd.read_csv("grid_search_done1.csv", index_col=0)

# %%
df["T"] = round(df["T"]/60).astype(np.int)

df
# Out:
#       l_rate      drop  batch_size  n_units   T   target0   target1   target2  \
# 0   0.650086  0.321736          50       76  34  1.001672  0.612849  0.995342
# 1   0.406472  0.273118          93       40  18  1.001672  0.613383  0.995503
# 2   0.784956  0.222661          99       63  23  1.001672  0.610006  0.995333
# 3   0.512890  0.399352          67       50  27  1.001672  0.629600  0.992346
# 4   0.455485  0.226154          71       33  22  1.001673  0.613908  1.001395
# 5   0.729514  0.256622          72       48  20  1.001672  0.609358  0.995151
# 6   0.124045  0.323637         107       66  25  1.001669  0.620912  0.995605
# 7   0.486404  0.259116          56       83  37  1.001672  0.610645  0.989883
# 8   0.518776  0.299725         136       32  14  1.001673  0.621351  0.996489
# 9   0.560668  0.283040          88       85  28  1.001672  0.615653  0.995087
# 10  0.378843  0.353140         128       42  19  1.001672  0.626240  0.996087
# ...

# %%
df[["target0", "target1", "target2", "target3"]].mean(axis = 1).sort_values()
# Out:
# 7     0.842200
# 14    0.850905
# 12    0.855364
# 9     0.856005
# 13    0.858298
# 2     0.859818
# 5     0.861362
# 0     0.872018
# 6     0.875212
# 1     0.881379
# 3     0.887116
# 10    0.888171
# 11    0.889658
# 8     0.897198
# 4     0.897925
# dtype: float64

# %%
def plot(x):
    df.sort_values(x).plot.line(x = x, y = ["target0", "target1", "target2", "target3"])
    plt.title("Random search for {}".format(x))
    plt.ylabel("val_loss")

# %%
plot("n_units")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = df["T"].sum()/60

# %%
(a - 6)*60
# Out:
# 26.000000000000014
